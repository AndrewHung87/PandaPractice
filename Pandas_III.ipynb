# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewHung87/PandaPractice/blob/main/Pandas_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
elections = pd.read_csv("elections.csv")

# %%
babynames = pd.read_csv("babynames.csv")

# %%
# dataframe.groupby(column_name).agg(aggregation_function)

babynames[["Year", "Count"]].groupby("Year").agg(sum)
# Out:
# <ipython-input-7-e6c010fa38cd>:3: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   babynames[["Year", "Count"]].groupby("Year").agg(sum)
#         Count
# Year
# 1910   516311
# 1911   565824
# 1912   888003
# 1913  1028578
# 1914  1293349
# ...       ...
# 2019  2912528
# 2020  2790976
# 2021  2833255
# 2022  2822007
# 2023  2745320
#
# [114 rows x 1 columns]

# %%
# Some commonly-used aggregation functions can even be called directly, without the explicit use of .agg( )
babynames.groupby("Year").mean(numeric_only=True)
# Out:
#           Count
# Year
# 1910  30.679838
# 1911  32.110777
# 1912  38.310669
# 1913  40.693860
# 1914  44.873673
# ...         ...
# 2019  30.903465
# 2020  29.968603
# 2021  29.749520
# 2022  29.442216
# 2023  28.879562
#
# [114 rows x 1 columns]

# %%
babynames.groupby("Year")[["Count"]].sum()
# Out:
#         Count
# Year
# 1910   516311
# 1911   565824
# 1912   888003
# 1913  1028578
# 1914  1293349
# ...       ...
# 2019  2912528
# 2020  2790976
# 2021  2833255
# 2022  2822007
# 2023  2745320
#
# [114 rows x 1 columns]

# %%
babynames.groupby("Year")[["Count"]].agg(sum)
# Out:
# <ipython-input-13-f0dc4b3970da>:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   babynames.groupby("Year")[["Count"]].agg(sum)
#         Count
# Year
# 1910   516311
# 1911   565824
# 1912   888003
# 1913  1028578
# 1914  1293349
# ...       ...
# 2019  2912528
# 2020  2790976
# 2021  2833255
# 2022  2822007
# 2023  2745320
#
# [114 rows x 1 columns]

# %%
import plotly.express as px

babies_by_year = babynames.groupby("Year")[["Count"]].agg(sum)
px.line(babies_by_year, y="Count")
# Out:
# <ipython-input-15-63755daac337>:3: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   babies_by_year = babynames.groupby("Year")[["Count"]].agg(sum)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
f_babynames = babynames[babynames["Gender"]=="F"]
f_babynames = f_babynames.sort_values(["Year"])
jenn_counts_series = f_babynames[f_babynames["Name"]=="Jennifer"]["Count"]

# %%
elections.groupby("Year").filter(lambda sf: sf["%"].max() < 45)
# Out:
#     Year             Candidate                Party  Popular vote Result  \
# 35  1860  John C. Breckinridge  Southern Democratic      847953.0   loss
# 36  1860       Abraham Lincoln           Republican     1860829.0    win
# 61  1912    Theodore Roosevelt          Progressive     4122721.0   loss
# 62  1912        Woodrow Wilson           Democratic     6296284.0    win
# 67  2016            Jill Stein                Green     1457226.0   loss
#
#             %
# 35  18.100000
# 36  39.820000
# 61  27.400000
# 62  41.840000
# 67   1.073699

# %%
elections_sorted_by_percent = elections.sort_values("%", ascending=False)
elections_sorted_by_percent.groupby("Party").first()
# Out:
#                        Year               Candidate  Popular vote Result  \
# Party
# Democratic             1828          Andrew Jackson      642806.0    win
# Democratic-Republican  1820            James Monroe      151271.0    win
# Federalist             1796              John Adams           NaN    win
# Green                  2016              Jill Stein     1457226.0   loss
# Independent            1788       George Washington           NaN    win
# Liberal Republican     1872          Horace Greeley     2834125.0   loss
# Libertarian            2020            Jo Jorgensen     1865724.0   loss
# National Republican    1828       John Quincy Adams      500897.0   loss
# National Union         1864         Abraham Lincoln     2213868.0    win
# Progressive            1912      Theodore Roosevelt     4122721.0   loss
# Republican             1920       Warren G. Harding    16144093.0    win
# Southern Democratic    1860    John C. Breckinridge      847953.0   loss
# ...

# %%
grouped_by_party = elections.groupby("Party")
grouped_by_party.groups
# Out:
# {'Democratic': [20, 22, 24, 25, 27, 30, 31, 34, 38, 39, 43, 46, 47, 49, 51, 54, 56, 58, 59, 62, 64, 65, 70, 73], 'Democratic-Republican': [5, 6, 8, 10, 12, 14, 16, 18, 19], 'Federalist': [1, 3, 4, 7, 9, 11, 13, 15], 'Green': [67, 69], 'Independent': [0, 2, 17], 'Liberal Republican': [42], 'Libertarian': [71], 'National Republican': [21], 'National Union': [37], 'Progressive': [61], 'Republican': [33, 36, 40, 41, 44, 45, 48, 50, 52, 53, 55, 57, 60, 63, 66, 68, 72], 'Southern Democratic': [35], 'Whig': [23, 26, 28, 29, 32]}

# %%
grouped_by_party.get_group("Federalist")
# Out:
#     Year            Candidate       Party  Popular vote Result     %
# 1   1788           John Adams  Federalist           NaN   loss   NaN
# 3   1792           John Adams  Federalist           NaN   loss   NaN
# 4   1796           John Adams  Federalist           NaN    win  53.4
# 7   1800           John Adams  Federalist           NaN   loss  38.6
# 9   1804  Charles C. Pinckney  Federalist           NaN   loss  27.2
# 11  1808  Charles C. Pinckney  Federalist           NaN   loss  35.3
# 13  1812       DeWitt Clinton  Federalist           NaN   loss  47.6
# 15  1816           Rufus King  Federalist           NaN   loss  19.4

# %%
babynames.groupby(["Year", "Gender"])[["Count"]].agg(sum).head(6)
# Out:
# <ipython-input-24-9aa26e9e4d59>:1: FutureWarning:
#
# The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#               Count
# Year Gender
# 1910 F       352089
#      M       164222
# 1911 F       372382
#      M       193442
# 1912 F       504298
#      M       383705

# %%
import numpy as np

babynames_pivot = babynames.pivot_table(
    index = "Year",     # rows (turned into index)
    columns = "Gender",    # column values
    values = ["Count"], # field(s) to process in each group
    aggfunc = np.sum,   # group operation
)
babynames_pivot.head(6)
# Out:
# <ipython-input-26-a2e798522b6d>:3: FutureWarning:
#
# The provided callable <function sum at 0x7c1851d65a80> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#          Count
# Gender       F       M
# Year
# 1910    352089  164222
# 1911    372382  193442
# 1912    504298  383705
# 1913    566972  461606
# 1914    696910  596439
# 1915    908532  781454

# %%
babynames_pivot = babynames.pivot_table(
    index = "Year",     # rows (turned into index)
    columns = "Gender",    # column values
    values = ["Count", "Name"],
    aggfunc = np.max,   # group operation
)
babynames_pivot.head(6)
# Out:
# <ipython-input-28-bb1ad4b62643>:1: FutureWarning:
#
# The provided callable <function max at 0x7c1851d66160> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#        Count          Name
# Gender     F     M       F        M
# Year
# 1910    2913  1326    Zula   Zennie
# 1911    3188  1672    Zula      Zeb
# 1912    4106  3067    Zula   Zollie
# 1913    4739  3706    Zula  Zigmund
# 1914    5981  5192    Zula  Zygmunt
# 1915    7970  6443  Zulema  Zygmunt
